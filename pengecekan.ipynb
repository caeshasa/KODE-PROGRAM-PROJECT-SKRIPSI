# %%
import pandas as pd

fact = pd.read_csv('fact_tables.csv', sep=';')
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       3 fact = pd.read_csv('fact_tables.csv', sep=';')
# ----> 4 df.head()
#
# NameError: name 'df' is not defined

# %%
fact = pd.read_csv('fact_tables.csv', sep=';')

# %%
fact.head()
fact.dtypes
# Out:
# Number                object
# creator               object
# ServiceType           object
# ProductGroup          object
# TicketType            object
# Priority              object
# Severity              object
# Status                object
# FaultArisingTime      object
# FaultClearingTime     object
# Duration             float64
# User_ID                int64
# Service_ID             int64
# Ticket_Type_ID         int64
# Status_ID              int64
# dtype: object

# %%
# 1. Memeriksa apakah ada missing values yang tersisa
print("Jumlah missing values per kolom:")
print(fact.isnull().sum())

# 2. Memeriksa apakah ada duplikat di data
print("\nJumlah duplikat:")
print(fact.duplicated().sum())
# Out:
# Jumlah missing values per kolom:
# Number               0
# creator              0
# ServiceType          0
# ProductGroup         0
# TicketType           0
# Priority             0
# Severity             0
# Status               0
# FaultArisingTime     0
# FaultClearingTime    0
# Duration             0
# User_ID              0
# Service_ID           0
# Ticket_Type_ID       0
# Status_ID            0
# dtype: int64
#
# Jumlah duplikat:
# 0

# %%
df = pd.read_csv("fact_tables.csv", sep=None, engine="python")
df.head()
# Out:
#           Number                           creator ServiceType   ProductGroup  \
# 0  VPN2506300209  CISO - Connectivity Surveillance     Revenue         IP VPN
# 1  VPN2506300208  CISO - Connectivity Surveillance     Revenue         IP VPN
# 2  IPT2506300206                CiSO - CIM Service           -     IP Transit
# 3  IPL2506300204                CiSO - CIM Service     Revenue           IPLC
# 4  HBV2506300202                CiSO - CIM Service           -  Hubbing Voice
#
#   TicketType Priority Severity  Status     FaultArisingTime  \
# 0      Fault       P2     High  Closed  2025-06-30 23:28:00
# 1      Fault       P2     High  Closed  2025-06-30 23:27:00
# 2    Request       P3   Medium  Closed  2025-06-30 23:07:00
# 3      Fault       P3     High  Closed  2025-06-30 22:49:00
# 4      Fault       P3   Medium  Closed  2025-06-30 22:22:00
#
#      FaultClearingTime   Duration
# 0  2025-07-02 08:30:19  33.038611
# 1  2025-06-30 23:33:27   0.107500
# ...

# %%
# 2. Cek panjang maksimal per kolom
df.apply(lambda col: col.astype(str).str.len().max())
# Out:
# Number               17
# creator              43
# ServiceType           7
# ProductGroup         32
# TicketType           11
# Priority              2
# Severity              8
# Status               21
# FaultArisingTime     19
# FaultClearingTime    19
# Duration             19
# dtype: int64

# %%
print(df.dtypes)
# Out:
# Number                object
# creator               object
# ServiceType           object
# ProductGroup          object
# TicketType            object
# Priority              object
# Severity              object
# Status                object
# FaultArisingTime      object
# FaultClearingTime     object
# Duration             float64
# dtype: object

# %%
# 2. Cek panjang maksimal per kolom
df.apply(lambda col: col.astype(str).str.len().max())
# Out:
# User_Name    43
# User_ID       2
# dtype: int64

# %%
print(df.dtypes)
# Out:
# User_Name    object
# User_ID       int64
# dtype: object

# %%
df = pd.read_csv("dim_ticket.csv", sep=None, engine="python") 
df.head()
# 2. Cek panjang maksimal per kolom
df.apply(lambda col: col.astype(str).str.len().max())
# Out:
# TicketType        11
# Priority           2
# Severity           8
# Ticket_Type_ID     2
# dtype: int64

# %%
print(df.dtypes)
# Out:
# TicketType        object
# Priority          object
# Severity          object
# Ticket_Type_ID     int64
# dtype: object

# %%
df = pd.read_csv("dim_service.csv", sep=None, engine="python") 
df.head()
# 2. Cek panjang maksimal per kolom
df.apply(lambda col: col.astype(str).str.len().max())
# Out:
# Service_Type      7
# Product_Group    32
# Service_ID        2
# dtype: int64

# %%
print(df.dtypes)
# Out:
# Service_Type     object
# Product_Group    object
# Service_ID        int64
# dtype: object

# %%
df = pd.read_csv("dim_status.csv", sep=None, engine="python") 
df.head()
# 2. Cek panjang maksimal per kolom
df.apply(lambda col: col.astype(str).str.len().max())
# Out:
# Status       21
# Status_ID     1
# dtype: int64

# %%
print(df.dtypes)
# Out:
# Status       object
# Status_ID     int64
# dtype: object

# %%
print("Jumlah missing values per kolom:")
print(df.isnull().sum())
print("\nJumlah duplikat:")
print(df.duplicated().sum())
print("\nTipe data setiap kolom:")
print(df.dtypes)
# Out:
# Jumlah missing values per kolom:
# Number,creator,ServiceType,ProductGroup,TicketType,Priority,Severity,Status,FaultArisingTime,FaultClearingTime,Duration    0
# dtype: int64
#
# Jumlah duplikat:
# 0
#
# Tipe data setiap kolom:
# Number,creator,ServiceType,ProductGroup,TicketType,Priority,Severity,Status,FaultArisingTime,FaultClearingTime,Duration    object
# dtype: object

# %%
print(df.dtypes)
# Out:
# Number,creator,ServiceType,ProductGroup,TicketType,Priority,Severity,Status,FaultArisingTime,FaultClearingTime,Duration    object
# dtype: object
